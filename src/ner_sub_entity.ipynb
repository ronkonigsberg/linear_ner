# %%
TRAIN_FILE_PATH = '/tmp/eng.train2'
TAG_FILE_PATH = '/tmp/my_eng2.testa'
BROWN_DIR = '/Users/konix/Workspace/nertagger/resources/brown-clusters'

from collections import defaultdict, Counter
from nertagger.parser import parse_conll_tagged, format_conll_tagged, parse_conll_train, format_conll_train
from nertagger.word import parsed_documents_to_words, words_to_parsed_documents
from nertagger.annotators.brown_clusters import parse_brown_clusters_directory

# %%
raw_data = open('/Users/konix/Workspace/nertagger/data/eng.train', 'rb').read()
training_words = parsed_documents_to_words(parse_conll_train(raw_data))

all_clusters_dict = parse_brown_clusters_directory(BROWN_DIR)
rcv1_dict = all_clusters_dict['brown-rcv1.clean.tokenized-CoNLL03.txt-c1000-freq1.txt']

cluster_to_type_histogram = defaultdict(Counter)
for word_ in training_words:
    if word_.gold_label != 'O':
        word_cluster = rcv1_dict[word_.text][0] if word_.text in rcv1_dict else None
        if word_cluster:
            cluster_to_type_histogram[word_cluster].update([word_.gold_label])

cluster_to_purity = {}
for cluster, cluster_type_histogram in cluster_to_type_histogram.iteritems():
    all_count = sum(cluster_type_histogram.values())
    common_count = cluster_type_histogram.most_common(1)[0][1]
    if all_count > 20:
        common_fraction = common_count / float(all_count)
        cluster_to_purity[cluster] = True if common_fraction > 0.9 else False

# %%
import random

def convert_entity_type(entity):
    entity_type = entity.entity_type
#     return entity_type + str(random.randint(0, 1) + 1)
    first_word = entity.words[0]
    word_cluster = rcv1_dict[first_word.text][0] if first_word.text in rcv1_dict else None
    if word_cluster and cluster_to_purity.get(word_cluster, False) and entity_type == 'MISC':
        return entity_type + 'pure'
    else:
        return entity_type

# %%
class Entity(object):
    def __init__(self, words, tag_attr='gold_label'):
        self.words = words
        self._tag_attr = tag_attr
    
    @property
    def text(self):
        return ' '.join([word.text for word in self.words])

    @property
    def entity_type(self):
        return getattr(self.words[0], self._tag_attr)[2:]
        
    
    def __str__(self):
        return "<%s: '%s'>" % (self.entity_type, self.text)
    
    def __repr__(self):
        return str(self)


def _get_word_tag(word, tag_attr='gold_label'):
    return getattr(word, tag_attr)[0] if word is not None else None

def _get_word_type(word, tag_attr='gold_label'):
    if word is None:
        return None
    word_tag = getattr(word, tag_attr)
    return None if word_tag == 'O' else word_tag[2:]

def get_entity_list(word_list):
    entity_list = []
    current_entyity_words = []
    for word in word_list:
        word_tag = _get_word_tag(word)
        word_type = _get_word_type(word)

        prev_word = None if word.sentence_index == 0 else word.sentence[word.sentence_index-1]
        prev_word_tag = _get_word_tag(prev_word)
        prev_word_type = _get_word_type(prev_word)

        if word_tag != 'I' or word_type != prev_word_type:
            if current_entyity_words:
                entity_list.append(Entity(current_entyity_words))
                current_entyity_words = []
        if word_tag != 'O':
            current_entyity_words.append(word)
    return entity_list

# %%
raw_data = open('/Users/konix/Workspace/nertagger/data/eng.train', 'rb').read()
training_words = parsed_documents_to_words(parse_conll_train(raw_data))
entity_list = get_entity_list(training_words)

for word_ in training_words:
    word_.tag = None

for entity in entity_list:
    entity_type = entity.entity_type
    new_entity_type = convert_entity_type(entity)
    for word in entity.words:
        word.gold_label = word.gold_label.replace(entity_type, new_entity_type)

converted_raw_data = format_conll_train(words_to_parsed_documents(training_words))
open(TRAIN_FILE_PATH, 'wb').write(converted_raw_data)

# %%
import re
pure_re = re.compile(' [BI]-(?:PER|ORG|LOC|MISC)pure')

y = None
def pure_repl(match):
    return 'pure' + match.group(0)

x = open("/tmp/my_eng2.testa", 'rb').read()
# x = pure_re.sub(pure_repl, x)
x = x.replace('MISCpure', 'MISC')
open("/tmp/my_eng2.testa", 'wb').write(x)

# %%
raw_data = open('/Users/konix/Workspace/nertagger/data/my_eng.testa.l1', 'rb').read()
normal_tagger_words = parsed_documents_to_words(parse_conll_tagged(raw_data))
raw_data = open('/tmp/my_eng2.testa', 'rb').read()
split_tagger_words = parsed_documents_to_words(parse_conll_tagged(raw_data))

for normal_word, split_word in zip(normal_tagger_words, split_tagger_words):
    if 'PER' in split_word.tag:
        normal_word.tag = split_word.tag
    elif 'PER' in normal_word.tag:
        normal_word.tag = 'O'

merged_raw_data = format_conll_tagged(words_to_parsed_documents(normal_tagger_words))
open('/tmp/blabla.a', 'wb').write(merged_raw_data)

# %%
len(normal_tagger_words), len(split_tagger_words)

# %%
word[0].tag

# %%
x = [word_ for word_ in training_words if 'MISC' in word_.gold_label and 'pure' not in word_.gold_label]

# %%
len([z for z in training_words if z.text in ['Ferrari', 'McLaren', 'Leeds', 'Wimbledon']])
# Out:
# 65

# %%
y = set([x_.text for x_ in x])

# %%
x = defaultdict(list)
for y_ in y:
    y_cluster = rcv1_dict[y_][0] if y_ in rcv1_dict else None
    y_cluster_type_hist = cluster_to_type_histogram[y_cluster] if y_cluster else None
    if y_cluster and y_cluster_type_hist and sum(y_cluster_type_hist.values()) > 20:
        x[y_cluster].append(y_)

for y_cluster, y_list in x.iteritems():
    y_cluster_type_hist = cluster_to_type_histogram[y_cluster]
    print y_cluster, y_cluster_type_hist
    for y_ in y_list:
        print '\t' + y_
# Out:
# 1101100011 Counter({'I-LOC': 21, 'I-MISC': 6, 'I-ORG': 6, 'I-PER': 6})
# 	Indian-ruled
# 	Pakistan-ruled
# 	British-ruled
# 	Palestinian-ruled
# 	Shabwa
# 1101100010 Counter({'I-PER': 31, 'I-MISC': 7, 'I-LOC': 5, 'I-ORG': 4})
# 	Serb-controlled
# 	Kurdish-controlled
# 	Serb-held
# 111111010 Counter({'I-MISC': 35, 'B-MISC': 1})
# 	100
# 	310
# 	95
# 	154
# 	215
# 	150
# 	4.0
# 11011011110 Counter({'I-MISC': 32, 'I-LOC': 11, 'I-ORG': 8, 'I-PER': 1, 'B-MISC': 1})
# 	Communist-led
# 	Arab
# 	Baltic
# 	Himalayan
# 	Islamic
# 	Andean
# 11101101111111 Counter({'I-ORG': 1126, 'I-LOC': 239, 'I-PER': 233, 'I-MISC': 26})
# 	Ferrari
# 	McLaren
# 	Leeds
# 	Wimbledon
# 11101101111110 Counter({'I-ORG': 18, 'I-LOC': 3, 'I-MISC': 1})
# 	Congress
# 1101100110 Counter({'I-LOC': 95, 'I-ORG': 49, 'I-MISC': 8})
# 	New
# 111011111010 Counter({'I-PER': 83, 'I-ORG': 54, 'I-LOC': 15, 'I-MISC': 11})
# 	du
# 	et
# 	de
# 	al
# 1101011010 Counter({'I-MISC': 36, 'I-ORG': 33, 'I-PER': 9, 'I-LOC': 8})
# 	Apertura
# 	PGA
# 	Bundesliga
# 	Aryan
# 	Test
# 	Supercup
# 	Tour
# 	Subaru
# 11100000 Counter({'I-LOC': 20, 'I-ORG': 13, 'I-MISC': 1, 'I-PER': 1})
# 	The
# 1110110111010 Counter({'I-LOC': 543, 'I-ORG': 61, 'I-PER': 30, 'I-MISC': 4})
# 	Australia
# 	Islam
# 	India
# 	Switzerland
# 1110110111011 Counter({'I-LOC': 1293, 'I-PER': 48, 'I-ORG': 31, 'I-MISC': 2})
# 	Poland
# 1110001010 Counter({'I-ORG': 13, 'I-MISC': 7, 'I-PER': 7})
# 	Creation
# 	Prices
# 	Play
# 	Production
# 110010 Counter({'I-ORG': 10, 'I-MISC': 8, 'I-LOC': 3, 'I-PER': 1})
# 	the
# 1110111110110 Counter({'I-ORG': 128, 'I-PER': 22, 'I-LOC': 20, 'I-MISC': 12})
# 	Western
# 	COMEX
# 111011011100 Counter({'I-LOC': 500, 'I-PER': 53, 'I-ORG': 51, 'I-MISC': 5, 'B-LOC': 1})
# 	Costa
# 	Vietnam
# 11101111110100 Counter({'I-ORG': 101, 'I-MISC': 57, 'I-LOC': 13, 'I-PER': 11, 'B-MISC': 3})
# 	CeBIT
# 	Republican-led
# 	National
# 	Clean
# 	Grand
# 	Nobel
# 	Scout
# 	Football
# 	Republican-controlled
# 1110111111101 Counter({'I-ORG': 143, 'I-LOC': 39, 'I-PER': 36, 'I-MISC': 3})
# 	Monde
# 	Leonean
# 	USA
# 111011010110 Counter({'I-LOC': 45, 'I-ORG': 5, 'I-MISC': 3, 'I-PER': 1})
# 	Kong
# 1011001111 Counter({'I-LOC': 20, 'I-PER': 9, 'I-MISC': 1, 'I-ORG': 1})
# 	Ratna
# 110110110010 Counter({'I-MISC': 155, 'I-ORG': 33, 'I-PER': 8, 'I-LOC': 4})
# 	English
# 	Australian
# 	Welsh
# 	Scottish
# 	ATP
# 	Rhineside
# 	Oriole
# 	Olympic
# 	Comprehensive
# 	Beijing-funded
# 	Mauritian
# 	Paralympic
# 1011010110 Counter({'I-ORG': 316, 'I-MISC': 44, 'B-ORG': 18, 'I-LOC': 2})
# 	CBF
# 	FI
# 	ERA
# 	CTBT
# 	ISO
# 	RBI
# 	CUP
# 01111111100 Counter({'I-ORG': 12, 'I-MISC': 8, 'I-LOC': 3, 'I-PER': 2})
# 	OF
# 1110111111011010 Counter({'I-ORG': 27, 'I-MISC': 5, 'I-LOC': 3, 'I-PER': 2, 'B-MISC': 1})
# 	Latin
# 	Social
# 	Formula
# 1110111111011011 Counter({'I-ORG': 59, 'I-LOC': 57, 'I-MISC': 16, 'I-PER': 7})
# 	Red
# 	Central
# 	West
# 	Hang
# 11011010110 Counter({'I-MISC': 122, 'I-ORG': 40, 'I-PER': 10, 'I-LOC': 5, 'B-MISC': 1})
# 	Tutsi
# 	Hindu
# 	Hitleresque
# 	Basque
# 	Marxist
# 	Roman
# 	Catholic
# 	Moslem
# 	Tamil
# 	Catalan
# 	Kurd
# 	Corsican
# 	Christian
# 	pro-Baghdad
# 	Maronite
# 	Maoist
# 	Kurdish
# 1101101100110 Counter({'I-MISC': 256, 'I-ORG': 19, 'I-LOC': 5})
# 	Indian
# 10110100 Counter({'I-ORG': 31, 'I-MISC': 25, 'I-LOC': 21, 'I-PER': 6, 'B-LOC': 3})
# 	CPI
# 	BSE
# 	HIV
# 	MRI
# 	l
# 	NIS
# 	EMU
# 	CJD
# 	TM
# 111011110000 Counter({'I-ORG': 65, 'I-LOC': 35, 'I-PER': 9, 'I-MISC': 1})
# 	Seng
# 11010011110 Counter({'I-ORG': 10, 'I-MISC': 8, 'I-LOC': 2, 'I-PER': 2})
# 	AK-47
# 	Xingfu
# 	Russian-made
# 	Kalashnikov
# 	Russian-built
# 	AK47
# 11010011111 Counter({'I-ORG': 11, 'I-MISC': 7, 'I-PER': 3, 'I-LOC': 1})
# 	Passat
# 	Romanian-registered
# 	Harrods
# 	Lancer
# 11101111111101 Counter({'I-ORG': 159, 'I-MISC': 22, 'I-PER': 11, 'I-LOC': 9, 'B-MISC': 2})
# 	Orange
# 	Orphan
# 	Financial
# 	Beautiful
# 	Ophran
# 	Yellow
# 	Stainless
# 	Independent
# 	Trident
# 	International
# 	Golf
# 	Flight
# 	Empire
# 11101111111100 Counter({'I-ORG': 222, 'I-MISC': 25, 'I-LOC': 9, 'I-PER': 5, 'B-LOC': 1})
# 	Safety
# 	Sexual
# 	Rules
# 	Producer
# 	Peace
# 	Economic
# 	Dynasty
# 	Consumer
# 	Industrial
# 	Iron
# 	Electricity
# 	Customs
# 	Aviation
# 	Mission
# 11100010010 Counter({'I-ORG': 17, 'I-PER': 17, 'I-MISC': 4, 'I-LOC': 2})
# 	One-month
# 	All
# 	Small
# 	Near
# 101101110111 Counter({'I-ORG': 15, 'I-MISC': 14, 'I-LOC': 5})
# 	Internet
# 	All-Star
# 	Olympiad
# 	Java
# 1110111100101 Counter({'I-ORG': 94, 'I-MISC': 92, 'I-PER': 3})
# 	Lakes
# 	League
# 	Prix
# 	Convention
# 	Slams
# 	Prize-winning
# 	Slam
# 	Award-winning
# 	Bowl
# 1110111100100 Counter({'I-LOC': 119, 'I-ORG': 116, 'I-MISC': 39, 'I-PER': 13})
# 	Republic
# 	Conference
# 	Player
# 	Championships
# 	Agreement
# 	Disease
# 	Academy
# 	Partnership
# 	Fighter
# 	Classic
# 	Rally
# 	Book
# 	Revolution
# 	Castle
# 	Law
# 110110101000 Counter({'I-MISC': 99, 'I-ORG': 3, 'I-LOC': 1, 'B-MISC': 1})
# 	Afghan
# 110110101001 Counter({'I-MISC': 83, 'B-MISC': 3})
# 	Islamist
# 01111111110 Counter({'I-ORG': 18, 'I-MISC': 7, 'I-LOC': 7, 'I-PER': 4})
# 	NETHERLANDS
# 	9002
# 1110111111011110 Counter({'I-MISC': 206, 'I-ORG': 18, 'I-LOC': 11, 'I-PER': 5, 'B-MISC': 1})
# 	Championship
# 	Cultural
# 	Series
# 	Trophy
# 	Creutzfeldt-Jakob
# 	Open
# 	Tennis
# 	Cup
# 11101101100 Counter({'I-LOC': 613, 'I-ORG': 574, 'I-PER': 13, 'I-MISC': 7, 'B-MISC': 1})
# 	Mass
# 	Brussels
# 	Oklahoma
# 	Arabic
# 	California
# 	Puerto
# 11101101101 Counter({'I-LOC': 269, 'I-ORG': 179, 'I-MISC': 19, 'I-PER': 8, 'B-MISC': 1})
# 	Atlanta
# 	Nasdaq
# 	IBIS
# 	Bombay
# 	Lusaka
# 	NASDAQ
# 	London
# 	Sahara
# 1110111111011001 Counter({'I-MISC': 64, 'I-ORG': 7, 'B-MISC': 1, 'I-LOC': 1})
# 	F.A.
# 	Hamlet
# 	World
# 	Champions
# 	Ryder
# 	UEFA
# 1110111111100 Counter({'I-LOC': 89, 'I-ORG': 76, 'I-MISC': 34, 'I-PER': 16})
# 	Lankan
# 	Masters
# 	Diego-based
# 	Petroleum
# 	War
# 	Lankans
# 	Angeles-based
# 11101101010 Counter({'I-LOC': 101, 'I-ORG': 53, 'I-MISC': 5})
# 	York-based
# 	Yorkers
# 	Yorker
# 	Zealander
# 	Year
# 1110110010 Counter({'I-ORG': 121, 'I-PER': 60, 'I-MISC': 32, 'I-LOC': 7, 'B-MISC': 1})
# 	S&P
# 	People
# 	Children
# 	Boards
# 	Price
# 	Jones
# 	MEES
# 	Winners
# 	Women
# 	DEM
# 	Men
# 	Davis
# 	Countries
# 1110110011 Counter({'I-PER': 226, 'I-ORG': 11, 'I-MISC': 2, 'I-LOC': 1})
# 	Bovary
# 1110111010110 Counter({'I-PER': 24, 'I-ORG': 5, 'I-MISC': 1})
# 	Kwai
# 1110111010111 Counter({'I-PER': 31, 'I-ORG': 12, 'I-MISC': 3, 'I-LOC': 1})
# 	Dutchman
# 1110111111011000 Counter({'I-ORG': 14, 'I-MISC': 5, 'I-LOC': 2})
# 	Universe
# 	Teen
# 0100 Counter({'I-ORG': 104, 'I-MISC': 20, 'I-LOC': 9, 'I-PER': 3})
# 	of
# 1101101100111 Counter({'I-MISC': 247, 'I-LOC': 57, 'I-ORG': 5})
# 	Canadian
# 	Brazilian
# 	Toronto-based
# 	German
# 	Bavarian
# 	Swiss
# 	Cyprus-based
# 	Norwegian
# 	Valuable
# 	Vancouver-based
# 	Belgian
# 	Slovak
# 	Polish
# 	Swedish
# 	French-registered
# 	British-based
# 	Malaysian
# 	Czech
# 11100011010 Counter({'I-LOC': 73, 'I-ORG': 30, 'I-MISC': 1})
# 	Farewell
# 11011001110 Counter({'I-LOC': 45, 'I-ORG': 5, 'I-MISC': 3, 'I-PER': 2})
# 	Hong
# 11011001111 Counter({'I-LOC': 13, 'I-ORG': 4, 'I-PER': 3, 'I-MISC': 2})
# 	Bovine
# 101001010 Counter({'I-MISC': 51, 'I-ORG': 24, 'I-LOC': 6, 'I-PER': 2})
# 	Democrats
# 	Catholics
# 	Republicans
# 	Saudis
# 	Palestinians
# 	Parisians
# 	Socialists
# 	Israelis
# 1110111100110 Counter({'I-ORG': 127, 'I-MISC': 20, 'I-LOC': 7})
# 	Prize
# 	Association
# 	Exploitation
# 	Code
# 	Impossible
# 	Area
# 	Council
# 	Committee
# 	Act
# 	Encyclopedia
# 110110010 Counter({'I-LOC': 97, 'I-MISC': 37, 'I-ORG': 26, 'I-PER': 10})
# 	Black
# 	North
# 	South
# 111011111101011 Counter({'I-ORG': 64, 'I-MISC': 57, 'I-LOC': 4, 'B-MISC': 4})
# 	Communist
# 	Super
# 	Reform
# 	Dust
# 	Democratic
# 	Jewish
# 	Democrat
# 110110101011 Counter({'I-MISC': 22, 'I-ORG': 8, 'I-LOC': 4, 'I-PER': 1})
# 	Yugoslav
# 	Soviet
# 	Stalinist
# 110110101010 Counter({'I-MISC': 132, 'I-ORG': 12, 'I-PER': 7, 'I-LOC': 1})
# 	Tibetan
# 	Croat
# 	Bosnian
# 	Chechen
# 	Israeli-Syrian
# 	Palestinian
# 	NATO-led
# 	Xhosa
# 	Serb
# 	Moslem-led
# 11100111 Counter({'I-PER': 3482, 'I-ORG': 93, 'I-LOC': 41, 'I-MISC': 15})
# 	Konrad
# 11100110 Counter({'I-PER': 370, 'I-MISC': 2, 'I-LOC': 1, 'I-ORG': 1})
# 	Bill
# 111110111110 Counter({'I-LOC': 62, 'I-ORG': 20, 'I-MISC': 13, 'I-PER': 1})
# 	States
# 	Nations
# 11011011010 Counter({'I-MISC': 109, 'I-LOC': 89, 'I-ORG': 36})
# 	British
# 	San
# 	Boston-based
# 	Finnish
# 	Sri
# 	Los
# 	Saudi
# 11101101111010 Counter({'I-LOC': 155, 'I-ORG': 36, 'I-MISC': 2})
# 	Trax
# 11101101111011 Counter({'I-LOC': 86, 'I-ORG': 13, 'I-PER': 9, 'I-MISC': 5})
# 	Betaseron
# 101001000 Counter({'I-MISC': 118, 'I-ORG': 8})
# 	Arabs
# 	Serbs
# 	Americans
# 	Moslems
# 1011001001 Counter({'I-LOC': 33, 'I-ORG': 8, 'I-MISC': 7, 'B-MISC': 1})
# 	East
# 	Eastern
# 11101111101110 Counter({'I-ORG': 8, 'I-MISC': 6, 'I-LOC': 4, 'I-PER': 3})
# 	F
# 	Jewel
# 1110110111110 Counter({'I-LOC': 225, 'I-PER': 83, 'I-ORG': 45, 'I-MISC': 8})
# 	Opthalmic
# 	Dolly
# 	France
# 	Edouard
# 1110111111011101 Counter({'I-MISC': 25, 'I-ORG': 21, 'I-LOC': 1, 'I-PER': 1})
# 	Miss
# 	Civil
# 	Waldbaum
# 	Third
# 	Fourth
# 	Singer
# 	Second
# 1110001110 Counter({'I-ORG': 35, 'I-LOC': 27, 'I-PER': 6, 'I-MISC': 4})
# 	SOUTH
# 	Grandstand
# 	LABOUR
# 11101101001 Counter({'I-LOC': 140, 'I-PER': 116, 'I-ORG': 49, 'I-MISC': 1})
# 	Forrest
# 11101101000 Counter({'I-LOC': 129, 'I-MISC': 8, 'I-PER': 1})
# 	Africans
# 	Africa
# 111011111111101 Counter({'I-ORG': 48, 'I-MISC': 2, 'I-PER': 1})
# 	Exchange
# 111011111111100 Counter({'I-ORG': 31, 'I-MISC': 2})
# 	Drug
# 01111110 Counter({'I-ORG': 39, 'I-MISC': 7, 'I-LOC': 4, 'I-PER': 1})
# 	Rican
# 	's
# 10110111000 Counter({'I-ORG': 149, 'I-LOC': 70, 'I-MISC': 39, 'I-PER': 11})
# 	Euro
# 	Olympics
# 	Netherlands
# 	Yankee
# 	Eco-Challenge
# 	Games
# 	GOP
# 	Nazis
# 	Zionists
# 1011001011 Counter({'I-LOC': 65, 'I-ORG': 34, 'I-MISC': 11, 'I-PER': 6, 'B-MISC': 1})
# 	Bharat
# 	Mediterranean
# 	Arctic
# 	Adriatic
# 	Gulf
# 110110110110 Counter({'I-LOC': 315, 'I-MISC': 39, 'I-ORG': 34, 'I-PER': 3})
# 	U.S.
# 	AL
# 1110000110 Counter({'I-LOC': 15, 'I-PER': 6, 'I-MISC': 3, 'I-ORG': 1})
# 	HONG
# 110110111111 Counter({'I-MISC': 62, 'I-LOC': 6, 'I-ORG': 4})
# 	Korea-based
# 	Korean-related
# 	African
# 	Korean
# 110110111110 Counter({'I-MISC': 60, 'I-ORG': 16, 'I-PER': 1})
# 	American
# 	Etruscan
# 	Asian
# 111011111001 Counter({'I-ORG': 165, 'I-PER': 53, 'I-MISC': 44, 'I-LOC': 38})
# 	La
# 	Beijing-backed
# 	Republican
# 	General
# 	Battle
# 	Air
# 	Frenchman
# 	Rocky
# 	Golden
# 	Sierra
# 	Proposition
# 111011111111111 Counter({'I-ORG': 98, 'I-LOC': 6, 'I-MISC': 2, 'I-PER': 2})
# 	Stock
# 111011000 Counter({'I-ORG': 930, 'I-PER': 140, 'I-LOC': 94, 'I-MISC': 47})
# 	Time
# 	GT
# 	Ford
# 	Butte
# 	Carnival
# 	Viacom
# 	Apache
# 	Block
# 	VW
# 	Mitsubishi
# 	Porsche
# 	Toyota
# 	BC
# 	Boy
# 	Airbus
# 	NEC
# 	Toshiba
# 	Boeing
# 11100010110 Counter({'I-LOC': 499, 'I-ORG': 125, 'I-MISC': 7, 'I-PER': 2})
# 	Tacis
# 	KONG
# 	BRUSSELS
# 	AFRICA
# 	CHICAGO
# 11111111111011 Counter({'I-LOC': 13, 'I-ORG': 8, 'I-MISC': 1})
# 	Middle
# 11101111011 Counter({'I-ORG': 242, 'I-PER': 19, 'I-MISC': 5, 'I-LOC': 2})
# 	II
# 	A310
# 11101111010 Counter({'I-ORG': 242, 'I-PER': 25, 'I-MISC': 19, 'I-LOC': 11, 'B-MISC': 2})
# 	Challenge
# 	Stakes
# 	Endurance
# 	Regulation
# 	Agent
# 	News
# 	Wars
# 	Survey
# 	County
# 1101101110 Counter({'I-MISC': 55, 'I-ORG': 31})
# 	European
# 111000100110 Counter({'I-MISC': 23, 'I-ORG': 5, 'I-LOC': 1})
# 	One-year
# 	No
# 	Two
# 	Four
# 	Seven
# 	Ten
# 	Division
# 	Five
# 111101101101110 Counter({'I-LOC': 45, 'I-ORG': 20, 'I-MISC': 1, 'I-PER': 1})
# 	Doncaster
# 111101101101111 Counter({'I-LOC': 18, 'I-ORG': 9, 'I-MISC': 2})
# 	1000
# 	Newbury
# 110101011110 Counter({'I-PER': 19, 'I-MISC': 4, 'I-ORG': 1})
# 	Brady
# 	pre-Soviet
# 11101010 Counter({'I-PER': 4184, 'I-ORG': 152, 'I-LOC': 38, 'I-MISC': 30})
# 	Saunders
# 	Hill
# 111011111101010 Counter({'I-ORG': 48, 'I-MISC': 11, 'B-ORG': 6})
# 	Liberian
# 	Independence
# 	Baath
# 	Labor
# 	Labour
# 	England-based
# 111011111000 Counter({'I-ORG': 141, 'I-LOC': 54, 'I-PER': 21, 'I-MISC': 9})
# 	Hall
# 	Provide
# 	Loretto
# 	Southern
# 	Old
# 	Operation
# 	Comfort
# 	First
# 	Testament
# 111110001111 Counter({'I-ORG': 28, 'I-LOC': 19, 'I-MISC': 10, 'I-PER': 6})
# 	Kadian
# 	Nazism
# 	Buzuku
# 	Fair
# 	Fame
# 101101010 Counter({'I-ORG': 37, 'I-LOC': 22, 'I-MISC': 17, 'I-PER': 2})
# 	Dow
# 	Taleban
# 	AEX
# 11101111001111 Counter({'I-ORG': 55, 'I-MISC': 5, 'I-LOC': 1, 'I-PER': 1})
# 	Community
# 	Commission
